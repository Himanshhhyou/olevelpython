# %% [markdown]
# # Table of contents
#
# 1. **[Function](#Function)**
# 2. **[Unbound Error](#Unbound-Error)**
# 3. **[Global Keyword](#Global-Keyword)**
# 4. **[Return Statement](#Return-Statement)**

# %% [markdown]
# ## Function

# %%
#Function creation
def myFun(num): 
    print(num*2)
#function call / calling
myFun(4) 
myFun(8)
myFun(5)

# %% [markdown]
# ## Unbound Error

# %%
a = 10
def fun():
    #a = a *2 #error
    b = a *2
    print(b)
fun()

# %% [markdown]
# ## Global Keyword

# %%
def fun():
    global a
    a = 7
    print(a)
fun()
print(a)

# %% [markdown]
# ## Return Statement

# %%
def fun(x,y):
    return x**2  ,y**2
    print("after return")
print(fun(4,2))

# %% [markdown]
# ## Doc String

# %%
def fact(num):
    """ This function calculates factorial.
        It takes any positive number.
        ex = 6 x 5 x 4 x 3 x 2 x 1 = 720
    """
    total = 1
    if num>0:
        while num > 0:
            total = num*total
            num = num-1
        return total
    else:
        return "Please enter positive number only"
    
print(fact(5))
print(fact.__doc__)

# %% [markdown]
# ## Parameter and Arguments

# %%
def greet(name): # parameter
    return f"Good Morning {name}"
greet('Himanshu') #argument

# %%
def greet(name,t): # parameters
    if t>4 and t<12:
        return f"Good Morning {name}"
    elif t>12 and t<16:
        return f"Good Afternoon {name}"
    elif t>16 and t<21:
        return f"Good Evening {name}"
    else:
        return f"Good Night {name}"

#function call
print(greet('Vishal',5)) #arguments

# %% [markdown]
# ## Positional or required arguments

# %%
def fun(b,a):
    return a,b
print(fun(4,6)) #positional
print(fun(3)) #required

# %%
#default argument
def greet(name="User"):
    return f"Hello {name}"
    
print(greet())

# %%
#keyword arguments
def voteCheck(name, age):
    msg = f"Hello {name}, you are {age} years old\n"
    d1 = "So you can vote"
    d2 = "So you can not vote"
    
    if age> 18:
        return msg + d1
    else:
        return msg + d2
        
res = voteCheck("Geeta",20)
print(res)
# Out:
# Hello Geeta, you are 20 years old
# So you can vote

# %%
# Variable length
def add(*total):
    return sum(total)
    
print(add(10,10))
print(add(10,70,2))
print(add(10,1))
print(add(10))
# Out:
# 20
# 82
# 11
# 10

# %%
def sumOfNum(*n):
    print("Sum",sum(n))

sumOfNum(6,7)
sumOfNum(6,7,2)
sumOfNum(6,7,8,2)
# Out:
# Sum 13
# Sum 15
# Sum 23

# %%
#variable length
def friend(*n):
    print(n)  #tuple
friend("ram","mohan","rohan")

#any number of keyword argument
def friend(**n): #dict
    print(f"{n["bFri"]} is my best  friend. He gives me ladoo")

friend(sFri = "ram", cFri = "mohan", bFri = "rohini")
# Out:
# ('ram', 'mohan', 'rohan')
# rohini is my best  friend. He gives me ladoo

# %%
book = {
    "name" : "Python",
    "Pub" : "TBalaji",
    "First" : 2021,
    "olevel" : True
}

for i in book.keys():
    print(i)
for i in book.values():
    print(i)
for i in book.items():
    print(i)
# Out:
# name
# Pub
# First
# olevel
# Python
# TBalaji
# 2021
# True
# ('name', 'Python')
# ('Pub', 'TBalaji')
# ('First', 2021)
# ('olevel', True)

# %%
## Lambda Function

# %%
a = lambda x,y,z : x**y*z
#def a(x,y):
#    return x+y
print(a(4,6,0))
# Out:
# 0

# %%
exp = input("Enter Expression: ")
print(eval(exp))
# Out:
# Enter Expression:  min(7,9,5)
# 5

# %%
import time
print(dir(time))
# Out:
# ['_STRUCT_TM_ITEMS', '__doc__', '__loader__', '__name__', '__package__', '__spec__', 'altzone', 'asctime', 'ctime', 'daylight', 'get_clock_info', 'gmtime', 'localtime', 'mktime', 'monotonic', 'monotonic_ns', 'perf_counter', 'perf_counter_ns', 'process_time', 'process_time_ns', 'sleep', 'strftime', 'strptime', 'struct_time', 'thread_time', 'thread_time_ns', 'time', 'time_ns', 'timezone', 'tzname']

# %%
name = "RamPrakash"
print(name.count('a'))
print(name.find('a'))
#if value not present  it return -1
#if multiple times target present , first occurance will return 

print(name.find('a',3,7))
print(name.find('a',6))


name  = "Prakash"
print(name.rfind("a"))
# Out:
# 3
# 1
# 5
# 7
# 4

# %%
name = input("Enter your name: ")
-name = name.strip() #remove spaces from left right

if name.find(" ") == -1:
    print("Please enter your lastname")
else:
    print("Hello",name)
# Out:
# Enter your name:  ram
# Please enter your lastname

# %%
s1 = "The Quick brown fox jumps over the lazy dog"
cap_sen = s1.capitalize()
title_sen = s1.title()
lower_sen = s1.lower()
upper_sen = s1.upper()
swap_sen = s1.swapcase()
print(cap_sen)
print(title_sen)
print(lower_sen)
print(upper_sen)
print(swap_sen)
# Out:
# The quick brown fox jumps over the lazy dog
# The Quick Brown Fox Jumps Over The Lazy Dog
# the quick brown fox jumps over the lazy dog
# THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG
# tHE qUICK BROWN FOX JUMPS OVER THE LAZY DOG

# %%
name = 'Priyanka'
print(name.islower())
print(name.isupper())
print(name.istitle())
# Out:
# False
# False
# True

# %%
#name1 = "Riya Riya Riya"
name2 = "Mayank mayank mayank"
#newName1 = name1.replace("ya","shab")
newName2 = name2.replace("nk","",2)
#print(newName1)
print(newName2)
# Out:
# Mayamayamayank

# %%
name  = "     ram     "
clear_name = name.strip() #Both Side
Lclear_name = name.lstrip() #Left Side
Rclear_name = name.rstrip() #Right Side
print(clear_name)
print(Lclear_name)
print(Rclear_name)
# Out:
# ram
# ram
#      ram

# %%
s1 = "Be a kind person"
p1 = s1.partition('kind')
p2 = s1.partition("a")
p3 = s1.partition(" ")
print(p1)
print(p2)
print(p3)
# Out:
# ('Birendra Kumar', '', '')
# ('Birendr', 'a', ' Kumar')
# ('Birendra', ' ', 'Kumar')

# %%
e1 = ("Ram","@gmail",".com")
e2 = ("Mohan","@yahoo",".com")
e3 = ("Rohan","@outlook",".com")
join_e1 = "".join(e1)
join_e2 = "".join(e2)
join_e3 = "".join(e3)
print(join_e1)
print(join_e2)
print(join_e3)
# Out:
# Ram@gmail.com
# Mohan@yahoo.com
# Rohan@outlook.com

# %%
e1 = "taaravaarav1443@yahoo.com"
e2 = "aarav353@gmail.com"
e3 = "kaarav33@outlook.com"

p1 = e1.partition("@")[2][:-4]
p2 = e2.partition("@")[2][:-4]
p3 = e3.partition("@")[2][:-4]

print(f"{p2} {p3} {p1}")
# Out:
# gmail outlook yahoo

# %%
#HW

# %%
msg = "Hey, meet me at 5pm. BTW 5pm is important!"

#q1
print('5pm present? ',end="")
if msg.find("9pm") != -1:
    print(True)
else:
    print(False)
    
#q2
new_msg  = msg.replace('BTW','By the way')
print(new_msg)

#q3
print(msg.find("important"))
# Out:
# 5pm present? False
# Hey meet me at 5pm By the way 5pm is important!
# 30

# %%
s1 = "    "
print(s1.isspace())
# Out:
# True

# %%
s1 = "Ram"
print(s1.isalpha())
# Out:
# True

# %%
s1 = "34646546"
print(s1.isdigit())
# Out:
# False

# %%
s1 = "Ram123"
print(s1.isalnum()) #alpha numeric
# Out:
# True

# %%
name = "Mr. Ram singh"
print(name.startswith("Mrs."))
# Out:
# False

# %%
name = input("Enter your name(include Mr./Mrs.): ").lower()
n = name[name.find(" ")+1:].title()

#mrs ram

if name.startswith("mrs"):
    print(f"{n} is my friend")
    print("She live in naini")
elif name.startswith('mr'):
    print(f"{n} is my friend")
    print("He live in naini")
else:
    print("Please include Mr. or Mrs.")

# %%
fruit = "Orange"
print(fruit.endswith('ange'))
# Out:
# True

# %%
name = "Ashϋtόsh"
print(name.encode(encoding = "ascii",errors="backslashreplace"))
print(name.encode(encoding = "ascii",errors="ignore"))
print(name.encode(encoding = "ascii",errors="namereplace"))

sc = "™µ≤∞Ω∑αβ"
for i in sc:
    print(i,end="  ==>  ")
    print(i.encode(encoding="ascii",errors="namereplace"))


sc = "µ≤∞Ω"
print(sc.encode(encoding="ascii",errors="xmlcharrefreplace"))
# Out:
# b'Ash\\u03cbt\\u03ccsh'
# b'Ashtsh'
# b'Ash\\N{GREEK SMALL LETTER UPSILON WITH DIALYTIKA}t\\N{GREEK SMALL LETTER OMICRON WITH TONOS}sh'
# ™  ==>  b'\\N{TRADE MARK SIGN}'
# µ  ==>  b'\\N{MICRO SIGN}'
# ≤  ==>  b'\\N{LESS-THAN OR EQUAL TO}'
# ∞  ==>  b'\\N{INFINITY}'
# Ω  ==>  b'\\N{OHM SIGN}'
# ∑  ==>  b'\\N{N-ARY SUMMATION}'
# α  ==>  b'\\N{GREEK SMALL LETTER ALPHA}'
# β  ==>  b'\\N{GREEK SMALL LETTER BETA}'
# b'&#181;&#8804;&#8734;&#8486;'

# %%
name = "Ram Singh"
e = name.encode('utf-8')
print(e)

d = e.decode('utf-8')
print(d)
# Out:
# b'Ram Singh'
# Ram Singh

# %%
import re

name = "Ram\nShyam"
print(name)

#^ ==> start
print(re.findall("^Ram",name))
#$ ==> end
print(re.findall("am$",name))

print(re.findall("[amy]",name)) #one one char
print(re.findall("\n",name)) #escape sequence
# Out:
# Ram
# Shyam
# ['Ram']
# ['a', 'm', 'y', 'a', 'm']
# ['\n']
# ['am']

# %%
import re
mob = "+919876789876"
f = re.findall("^\+91",mob)
print(f)
if "+91" in f:
    print("Indian MOB")
else:
    print("Not Indian MOB")
# Out:
# ['+91']
# Indian MOB
# <>:3: SyntaxWarning: invalid escape sequence '\+'
# <>:3: SyntaxWarning: invalid escape sequence '\+'
# C:\Users\Himanshu\AppData\Local\Temp\ipykernel_16512\2582119910.py:3: SyntaxWarning: invalid escape sequence '\+'
#   f = re.findall("^\+91",mob)

# %%
#email id valid or not
def checkEmail():
    email = input("Enter your mail id: ")
    f = re.findall("@gmail.com$",email)

    if "@gmail.com" in f:
        print("Valid email")
    else:
        checkEmail() #recursion
checkEmail()
# Out:
# Enter your mail id:  arerar
# Enter your mail id:  aeraewr
# Enter your mail id:  4534
# Enter your mail id:  ertew
# Enter your mail id:  twert
# Enter your mail id:  wert
# Enter your mail id:  wer
# Enter your mail id:  tew
# Enter your mail id:  rt
# Enter your mail id:  wert
# Enter your mail id:  wert
# Enter your mail id:  wer
# Enter your mail id:  e
# Enter your mail id:  wrt
# Enter your mail id:  erwt
# Enter your mail id:  e
# Enter your mail id:  tr@gmail
# Enter your mail id:  tr@gmail.com
# Valid email

# %%
https://www.website.com

http://www.website.com

Website secure or not

# %%
import math
n = 36.82846

print("Round 2 digit after decimal: ",round(n,2))
print("Round: ",round(n))

print("Ceil: ",math.ceil(n))
print("Floor: ",math.floor(n))
print("sqrt: ",math.sqrt(16))
print("Fabs: ",math.fabs(-90))
print("Factorial: ",math.factorial(4))
print("GCD: ",math.gcd(15,25))
print("Fmod: ",math.fmod(55,2))
#print("Remainder: ",math.remainder(55,2))
#print("Remainder: ",math.remainder(45,2))
print("Exp: ",math.exp(3)) #e^3   ==> 2.71



print("Divmod ",divmod(25,2))
# Out:
# Round 2 digit after decimal:  36.83
# Round:  37
# Ceil:  37
# Floor:  36
# sqrt:  4.0
# Fabs:  90.0
# Factorial:  24
# GCD:  5
# Fmod:  1.0
# Remainder:  -1.0
# Remainder:  1.0
# Exp:  54.598150033144236
# Divmod  (12, 1)

# %%
## Random

import random

print(random.random()) #between 0 and 1
print(int(random.random()*10)) #between 0 and 9
print(int(random.random()*10)+1) #between 1 and 10


print(random.randrange(5))
print(random.randrange(5,15))
print(random.randrange(5,15,2)) #begin, end, step
# Out:
# 0.973567805417263
# 8
# 10
# 2
# 10
# 14

# %%
## Date and time

import datetime

print(datetime.date.today())
print(datetime.date.today().day)
print(datetime.date.today().month)
print(datetime.date.today().year)
print(datetime.date.today().weekday())

print(datetime.datetime.now())
#0 - monday  6 - sunday
# Out:
# 2025-11-27
# 27
# 11
# 2025
# 3
# 2025-11-27 08:10:12.466896
