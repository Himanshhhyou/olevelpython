# %%
# Table of contents

1. **[Function](#Function)**
2. **[Unbound Error](#Unbound-Error)**
3. **[Unbound Error](#Unbound-Error)**

# %% [markdown]
# ## Function

# %%
#Function creation
def myFun(num): 
    print(num*2)
#function call / calling
myFun(4) 
myFun(8)
myFun(5)
# Out:
# 8
# 16
# 10

# %% [markdown]
# ## Unbound Error

# %%
a = 10
def fun():
    #a = a *2 #error
    b = a *2
    print(b)
fun()
# Out:
# 20

# %% [markdown]
# ## Global Keyword

# %%
def fun():
    global a
    a = 7
    print(a)
fun()
print(a)

# %% [markdown]
# ## Return statement
